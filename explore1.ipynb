# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('/Users/joshstrupp/Documents/Working/Educational/MSDV/MS2/ms2-thesis-FE/all_self_help.csv')

# Print all column names
print("Column Names:")
for col in df.columns:
    print(f"- {col}")

# Print an example of each column using the first record
print("\nExample Values (First Record):")
for col in df.columns:
    print(f"{col}: {df[col].iloc[0]}")
# Out:
# Column Names:
# - name
# - url
# - id
# - author
# - star_rating
# - num_ratings
# - num_reviews
# - summary
# - genres
# - first_published
# - about_author
# - community_reviews
# - kindle_price
# - publication_year
# - audience_cat
# - author_bio
# - author_clean
# - author_cred
# - author_num_books
# - author_num_followers
# - book_type
# - bt_source
# - combined_text
# - cred_reason
# - cred_score
# - currently_reading
# - embedding
# - historical_context
# - image_url
# - is_bt
# - key_cat_primary
# - key_cat_secondary
# - keyword_single
# - keywords
# - kindle_price_clean
# - methodology_clean
# - num_studies
# - problem_cat
# - problem_origin
# - problem_sentence
# - proof_of_creds
# - publication_reason
# - solution_cat
# - spectrum_clean
# - style_clean
# - tone_clean
# - usa_events
# - want_to_read
# - year_published
# - genres_lower
#
# Example Values (First Record):
# name: Believe and Achieve: W. Clement Stone's 17 Principles of Success
# ...
